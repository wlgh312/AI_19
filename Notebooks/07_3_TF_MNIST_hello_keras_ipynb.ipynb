# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  #tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(600, activation=tf.nn.relu),
  
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 600)               471000
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                6010
# =================================================================
# Total params: 477,010
# Trainable params: 477,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
param1=(784*512)+512
param2=(512*10)+10
param=param1+param2
print(param)
# Out:
# 407050

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 19s 317us/sample - loss: 0.1975 - acc: 0.9417
# Epoch 2/5
# 60000/60000 [==============================] - 19s 308us/sample - loss: 0.0777 - acc: 0.9755
# Epoch 3/5
# 60000/60000 [==============================] - 20s 327us/sample - loss: 0.0523 - acc: 0.9838
# Epoch 4/5
# 60000/60000 [==============================] - 19s 311us/sample - loss: 0.0346 - acc: 0.9889
# Epoch 5/5
# 60000/60000 [==============================] - 19s 313us/sample - loss: 0.0270 - acc: 0.9910

# %% [markdown]
# ### *Real World Challenge*: Large difference between training and testing set accuracy

# %% [markdown]
# #### Test accuracy

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.0866 - acc: 0.9743
# [0.0866305941292143, 0.9743]

# %% [markdown]
# #### Training accuracy

# %%
model.evaluate(x_train, y_train)
# Out:
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0283 - acc: 0.9907
# [0.028289161128174357, 0.9907167]
